# %% [markdown]
# <a href="https://colab.research.google.com/github/MollieGoon/MIS28002/blob/main/HelloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello world")
# Out:
# hello world

# %%
("mis is best!")
# Out:
# 'mis is best!'
